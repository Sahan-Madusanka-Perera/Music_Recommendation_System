# %% [markdown]
# # **Music Recommendation System - EfficientNet B0**

# %% [markdown]
# ## **1. Setup & Data Loading**

# %% [markdown]
# Drive Link for Cleaned ans split data : [https://drive.google.com/drive/folders/1p7if9OludoXyG-R9y96LFIhwjTogucB9?usp=sharing]

# %%
# Install required packages
# !pip install -q scikit-learn matplotlib seaborn
# !pip install -q keras-tuner

# Import libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import precision_recall_fscore_support


import tensorflow as tf
from tensorflow import keras
import keras_tuner as kt
from tensorflow.keras.applications import EfficientNetB0
#from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Conv2D
#from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator # Import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy
# Out:
# 2025-11-04 16:59:33.431042: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762275573.640053      37 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762275573.703513      37 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Check GPU availability
print("GPU Available:", tf.config.list_physical_devices('GPU'))
print("TensorFlow version:", tf.__version__)
# Out:
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# TensorFlow version: 2.18.0

# %%
# Configuration
DRIVE_PATH = Path("/kaggle/input/emotion-recognition-cleaned-data") 
MODEL_SAVE_PATH = Path("/kaggle/working")
MODEL_SAVE_PATH.mkdir(exist_ok=True)


TARGET_CLASSES = ['angry', 'happy', 'sad', 'stressed', 'neutral']
IMG_SIZE = (48, 48)
BATCH_SIZE = 25
EPOCHS = 50
LEARNING_RATE = 0.001

# %%
# Load cleaned data from drive

train_data = np.load(DRIVE_PATH / "train.npz")
val_data = np.load(DRIVE_PATH / "val.npz")
test_data = np.load(DRIVE_PATH / "test.npz")

#unpacking the data from  .npz files into separate variables for easier use.
X_train, y_train = train_data['images'], train_data['labels']
X_val, y_val = val_data['images'], val_data['labels']
X_test, y_test = test_data['images'], test_data['labels']

# Clean up to free memory
train_data.close()
val_data.close()
test_data.close()
del train_data, val_data, test_data

print("Successfully loaded and unpacked the datasets from Drive.")
# Out:
# Successfully loaded and unpacked the datasets from Drive.

# %% [markdown]
# ## **2. Data set Overview**

# %%
# Dataset Shape
print(f"Dataset shapes:")
print(f"Train: {X_train.shape}, Val: {X_val.shape}, Test: {X_test.shape}")


print (" ")

# Dataset Labels
print("Label shapes:", y_train.shape, y_val.shape, y_test.shape)
print("Sample labels:", y_train[:10])
print("Unique labels:", np.unique(y_train))

print (" ")

##### Calculate Data count per class

# Count occurrences per set
train_counts = [np.sum(y_train == i) for i in range(len(TARGET_CLASSES))]
val_counts = [np.sum(y_val == i) for i in range(len(TARGET_CLASSES))]
test_counts = [np.sum(y_test == i) for i in range(len(TARGET_CLASSES))]

# Create table
table = pd.DataFrame({
    'Class Index': range(len(TARGET_CLASSES)),
    'Class Name': TARGET_CLASSES,
    'Train Count': train_counts,
    'Validation Count': val_counts,
    'Test Count': test_counts
})

# Add total row
total_row = pd.DataFrame({
    'Class Index': ['-'],
    'Class Name': ['Total'],
    'Train Count': [np.sum(train_counts)],
    'Validation Count': [np.sum(val_counts)],
    'Test Count': [np.sum(test_counts)]
})

table = pd.concat([table, total_row], ignore_index=True)

print(table)
# Out:
# Dataset shapes:
# Train: (21970, 48, 48), Val: (5495, 48, 48), Test: (7092, 48, 48)
#
# Label shapes: (21970,) (5495,) (7092,)
# Sample labels: [3 3 3 2 3 1 2 4 1 2]
# Unique labels: [0 1 2 3 4]
#
#   Class Index Class Name  Train Count  Validation Count  Test Count
# 0           0      angry         3383               846        1055
# 1           1      happy         5668              1417        1767
# 2           2        sad         3779               945        1241
# 3           3   stressed         5250              1313        1804
# 4           4    neutral         3890               974        1225
# 5           -      Total        21970              5495        7092

# %% [markdown]
# - This confirms  labels are integer-encoded, not one-hot encoded.
# - range from 0 to 4
# - so use ->  *sparse_categorical_crossentropy*

# %% [markdown]
# ## **3. Class Weight Calculation**

# %%
#calculated only for train set.
#For imbalance handling

print("\nCalculating class weights (training set only)...")
class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weights = {i: weight for i, weight in enumerate(class_weights_array)}
print("Class weights:")
for i, (cls, weight) in enumerate(zip(TARGET_CLASSES, class_weights_array)):
    print(f"  {cls}: {weight:.3f}")
# Out:
# Calculating class weights (training set only)...
# Class weights:
#   angry: 1.299
#   happy: 0.775
#   sad: 1.163
#   stressed: 0.837
#   neutral: 1.130

# %% [markdown]
# ## **4. Data Preprocessing**

# %%
def preprocess_images(images):

    print(f"Preprocessing {images.shape[0]} images...")

    # Convert pixel values to float32 and normalize to [0, 1]
    images = images.astype('float32') / 255.0

    # Add a channel dimension if missing
    if len(images.shape) == 3:
        images = images[..., np.newaxis]

    return images  #Return the processed images as single-channel (grayscale

# %%
# Preprocess all datasets
X_train = preprocess_images(X_train)
X_val = preprocess_images(X_val)
X_test = preprocess_images(X_test)

print(f"After preprocessing:")
print(f"Train: {X_train.shape}, Val: {X_val.shape}, Test: {X_test.shape}")

# Free memory
import gc
gc.collect()
# Out:
# Preprocessing 21970 images...
# Preprocessing 5495 images...
# Preprocessing 7092 images...
# After preprocessing:
# Train: (21970, 48, 48, 1), Val: (5495, 48, 48, 1), Test: (7092, 48, 48, 1)
# 4

# %% [markdown]
# ## **5. Data Augmentation & Data Generators**

# %% [markdown]
# - Augmentation - for Train set only
#
#
#       - Rotation(15%)
#       - Width/height shifts (0.15)
#       - Horizontal flip
#       -  Zoom (0.15)
#       - Shear (0.1)
#
# - Data generators - for Train and validation  only

# %%
# Data Augmentation (aggressive for better generalization)
train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.15,
    height_shift_range=0.15,
    horizontal_flip=True,
    zoom_range=0.15,
    shear_range=0.1,
    fill_mode='nearest'
)

# No augmentation for validation/test
val_datagen = ImageDataGenerator()

# %%
# Create data generators (not for test set)
print("Creating data generators...")
train_generator = train_datagen.flow(X_train, y_train, batch_size=BATCH_SIZE, shuffle=True)
val_generator = val_datagen.flow(X_val, y_val, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# Creating data generators...

# %% [markdown]
# ## **6. Model Architecture Design**

# %% [markdown]
# - Build EfficientNet B0 architecture from scratch
#
#
#       - Expansion phase:
#       Temporarily increase the number of channels to let the block learn more features by expand_ratio (if >1)
#
#       - Depthwise conv:
#       extract spatial features per channel without increasing channels
#
#       - Squeeze-Excitation (SE):
#        Learns which channels are important → scales them.Improves model’s ability to focus on relevant features.
#
#       - Dropout:
#       Regularization-Randomly drops some features → prevents overfitting.(if dropout_rate > 0)
#
#       - Projection phase:
#       Reduces channels back to desired output_filters.
#
#       - Skip connection:
#       Adds input to output if shapes match → helps gradient flow, stabilizes training.
#
#       - All layers:
#       BatchNorm + Swish activation

# %%
# Define MBConv block for EfficientNet

def mbconv_block(inputs,    #input tensor
                 input_filters,    #number of channels in the input.
                 output_filters,   #number of channels to output after the block.
                 kernel_size=3,    #size of convolution filter
                 strides=1,     #step size for moving the filter
                 expand_ratio=1,   #how much to expand channels before depthwise conv
                 se_ratio=0.25,   #how much to reduce channels inside the squeeze-excitation step
                 block_id=0,    #block number- unique
                 dropout_rate=0.0):  #how much dropout to apply (regularization)


    prefix = f'block{block_id}_'   #name for the block’s layers
    filters = input_filters * expand_ratio  #channel size inside the block


    # Expansion phase
    if expand_ratio != 1:
        x = layers.Conv2D(filters, 1, padding='same', use_bias=False, name=prefix + 'expand_conv')(inputs)
        x = layers.BatchNormalization(name=prefix + 'expand_bn')(x)
        x = layers.Activation('swish', name=prefix + 'expand_activation')(x)
    else:
        x = inputs  #no expansion needed, just pass input as-is

    # Depthwise convolution
    x = layers.DepthwiseConv2D(kernel_size, strides=strides, padding='same', use_bias=False, name=prefix + 'dwconv')(x)
    x = layers.BatchNormalization(name=prefix + 'bn')(x)
    x = layers.Activation('swish', name=prefix + 'activation')(x)

    # Squeeze and Excitation
    if se_ratio > 0:
        se_filters = max(1, int(input_filters * se_ratio))
        se = layers.GlobalAveragePooling2D(name=prefix + 'se_squeeze')(x)
        se = layers.Reshape((1, 1, filters), name=prefix + 'se_reshape')(se)
        se = layers.Conv2D(se_filters, 1, activation='swish', name=prefix + 'se_reduce')(se)
        se = layers.Conv2D(filters, 1, activation='sigmoid', name=prefix + 'se_expand')(se)
        x = layers.Multiply(name=prefix + 'se_excite')([x, se])

    # Add dropout for regularization
    if dropout_rate > 0:
        x = layers.Dropout(dropout_rate, name=prefix + 'dropout')(x)

    # Projection phase
    x = layers.Conv2D(output_filters, 1, padding='same', use_bias=False, name=prefix + 'project_conv')(x)
    x = layers.BatchNormalization(name=prefix + 'project_bn')(x)

    # Skip connection
    if strides == 1 and input_filters == output_filters:
        x = layers.Add(name=prefix + 'add')([inputs, x])

    return x

# %% [markdown]
# ## **7.Model Build**

# %% [markdown]
#     - Input: 48×48×1 grayscale images
#     - Tunable stem conv:   First layer (24-48 filters, step 8, default 32)
#     - 16 MBConv blocks:  Progressively increase channels (16→24→40→80→112→192→320)
#     - Tunable parameters:  mbconv_dropout (0.0-0.2), se_ratio (0.1-0.3)
#     - Top conv:   1×1 conv with tunable filters (1024-1536, default 1280)
#     - Global pooling:    Reduces spatial dims to single vector
#     - Classification head: 3 dense layers (tunable units + dropout)
#     - Output:    Softmax for multi-class classification
#     - Optimizer:   Adam with tunable learning rate (1e-4 to 1e-2, log scale)

# %%
def build_model(hp):

    #input(48*48*1)
    inputs = layers.Input(shape=(48, 48, 1), name='grayscale_input')

    # Tunable stem conv layer
    stem_filters = hp.Int('stem_filters', min_value=24, max_value=48, step=8, default=32)

    x = layers.Conv2D(stem_filters, 3, strides=2, padding='same', use_bias=False,
                     kernel_initializer='he_normal', name='stem_conv')(inputs)
    x = layers.BatchNormalization(name='stem_bn')(x)
    x = layers.Activation('swish', name='stem_activation')(x)

    # Tunable dropout rate for MBConv blocks
    mbconv_dropout = hp.Float('mbconv_dropout', min_value=0.0, max_value=0.2, step=0.05, default=0.1)

    # Tunable SE ratio
    se_ratio = hp.Float('se_ratio', min_value=0.1, max_value=0.3, step=0.05, default=0.25)

    # MBConv blocks with tunable parameters
    x = mbconv_block(x, stem_filters, 16, kernel_size=3, strides=1, expand_ratio=1,
                    se_ratio=se_ratio, block_id=0, dropout_rate=mbconv_dropout)

    x = mbconv_block(x, 16, 24, kernel_size=3, strides=2, expand_ratio=6,
                    se_ratio=se_ratio, block_id=1, dropout_rate=mbconv_dropout)
    x = mbconv_block(x, 24, 24, kernel_size=3, strides=1, expand_ratio=6,
                    se_ratio=se_ratio, block_id=2, dropout_rate=mbconv_dropout)

    x = mbconv_block(x, 24, 40, kernel_size=5, strides=2, expand_ratio=6,
                    se_ratio=se_ratio, block_id=3, dropout_rate=mbconv_dropout)
    x = mbconv_block(x, 40, 40, kernel_size=5, strides=1, expand_ratio=6,
                    se_ratio=se_ratio, block_id=4, dropout_rate=mbconv_dropout)

    x = mbconv_block(x, 40, 80, kernel_size=3, strides=2, expand_ratio=6,
                    se_ratio=se_ratio, block_id=5, dropout_rate=mbconv_dropout)
    x = mbconv_block(x, 80, 80, kernel_size=3, strides=1, expand_ratio=6,
                    se_ratio=se_ratio, block_id=6, dropout_rate=mbconv_dropout)
    x = mbconv_block(x, 80, 80, kernel_size=3, strides=1, expand_ratio=6,
                    se_ratio=se_ratio, block_id=7, dropout_rate=mbconv_dropout)

    x = mbconv_block(x, 80, 112, kernel_size=5, strides=1, expand_ratio=6,
                    se_ratio=se_ratio, block_id=8, dropout_rate=mbconv_dropout)
    x = mbconv_block(x, 112, 112, kernel_size=5, strides=1, expand_ratio=6,
                    se_ratio=se_ratio, block_id=9, dropout_rate=mbconv_dropout)
    x = mbconv_block(x, 112, 112, kernel_size=5, strides=1, expand_ratio=6,
                    se_ratio=se_ratio, block_id=10, dropout_rate=mbconv_dropout)

    x = mbconv_block(x, 112, 192, kernel_size=5, strides=2, expand_ratio=6,
                    se_ratio=se_ratio, block_id=11, dropout_rate=mbconv_dropout)
    x = mbconv_block(x, 192, 192, kernel_size=5, strides=1, expand_ratio=6,
                    se_ratio=se_ratio, block_id=12, dropout_rate=mbconv_dropout)
    x = mbconv_block(x, 192, 192, kernel_size=5, strides=1, expand_ratio=6,
                    se_ratio=se_ratio, block_id=13, dropout_rate=mbconv_dropout)
    x = mbconv_block(x, 192, 192, kernel_size=5, strides=1, expand_ratio=6,
                    se_ratio=se_ratio, block_id=14, dropout_rate=mbconv_dropout)

    x = mbconv_block(x, 192, 320, kernel_size=3, strides=1, expand_ratio=6,
                    se_ratio=se_ratio, block_id=15, dropout_rate=mbconv_dropout)

    # Tunable top conv filters
    top_filters = hp.Int('top_filters', min_value=1024, max_value=1536, step=128, default=1280)
    x = layers.Conv2D(top_filters, 1, padding='same', use_bias=False, name='top_conv')(x)
    x = layers.BatchNormalization(name='top_bn')(x)
    x = layers.Activation('swish', name='top_activation')(x)
    x = layers.GlobalAveragePooling2D(name='avg_pool')(x)

    # Tunable classification head
    dense1_units = hp.Int('dense1_units', min_value=256, max_value=768, step=128, default=512)
    dense1_dropout = hp.Float('dense1_dropout', min_value=0.3, max_value=0.7, step=0.1, default=0.5)

    dense2_units = hp.Int('dense2_units', min_value=128, max_value=384, step=64, default=256)
    dense2_dropout = hp.Float('dense2_dropout', min_value=0.2, max_value=0.5, step=0.1, default=0.3)

    dense3_units = hp.Int('dense3_units', min_value=64, max_value=192, step=32, default=128)
    dense3_dropout = hp.Float('dense3_dropout', min_value=0.1, max_value=0.4, step=0.1, default=0.2)

    x = layers.Dense(dense1_units, activation='relu', name='dense_1')(x)
    x = layers.Dropout(dense1_dropout, name='dropout_1')(x)
    x = layers.Dense(dense2_units, activation='relu', name='dense_2')(x)
    x = layers.Dropout(dense2_dropout, name='dropout_2')(x)
    x = layers.Dense(dense3_units, activation='relu', name='dense_3')(x)
    x = layers.Dropout(dense3_dropout, name='dropout_3')(x)


    #Output Layer
    outputs = layers.Dense(len(TARGET_CLASSES), activation='softmax', name='classification_head')(x)

    model = keras.Model(inputs=inputs, outputs=outputs, name='efficientnetb0_grayscale_tuned')

    # Tunable learning rate
    learning_rate = hp.Float('learning_rate', min_value=1e-4, max_value=1e-2,
                           sampling='LOG', default=1e-3)

    # Model Compilation
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss=SparseCategoricalCrossentropy(from_logits=False), #false -> model’s final layer uses softmax activation
        metrics=[SparseCategoricalAccuracy(name='accuracy')]
    )

    return model

# %% [markdown]
# ## **8. Hyperparameter Tuning**

# %% [markdown]
# - Automatically finds best hyperparameters for the model using Keras Tuner
#
#       - Initializes RandomSearch tuner - tests different hyperparameter combinations
#       - Sets up callbacks - EarlyStopping + ReduceLROnPlateau for efficient training
#       - Runs search - trains 25 epochs per trial, evaluates on validation data
#       - Finds best hyperparameters - selects top performing configuration

# %%
def run_hyperparameter_tuning(X_train, y_train, X_val, y_val, class_weights, max_trials=20):


    print(f"Starting tuning with {max_trials} trials...")

    # Initialize tuner- Uses RandomSearch from Keras Tuner
    tuner = kt.RandomSearch(   #tries random hyperparameter combinations
        hypermodel=build_model,  #builds the  model (with tunable params)
        objective='val_accuracy', # Maximize val_accuracy
        max_trials=max_trials,  # number of hyperparameter sets to test. (default 20)
        executions_per_trial=1,
        directory='/kaggle/working/tuner_results',  #save directory in drive
        project_name='efficientnet_emotion'
    )

    # Callbacks
    callbacks = [
        #Stops if val_accuracy doesn't improve (patience=5)
        EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True),
        #Reduces learning rate if val_loss plateaus (patience=3)
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-7)
    ]

    # Search for Best Hyperparameters
    tuner.search( #runs training multiple times with different hyperparameters.
        X_train, y_train,
        validation_data=(X_val, y_val),  # evaluates each model on val set.
        epochs=25,   #Trains each configuration for 25 epochs
        batch_size=BATCH_SIZE, #mini-batch size during training.
        class_weight=class_weights,  #class weights for imbalanced data
        callbacks=callbacks,
        verbose=1
    )

    # Returns tuner object and best hyperparameters
    best_hps = tuner.get_best_hyperparameters(1)[0]

    print("\n" + "-"*60)
    print("\nBest hyperparameters:")
    for key in ['learning_rate', 'stem_filters', 'top_filters', 'se_ratio',
                'mbconv_dropout', 'dense1_units', 'dense1_dropout']:
        print(f"{key}: {best_hps.get(key)}")

    return tuner, best_hps

# %% [markdown]
# ## **9.Model Training**

# %% [markdown]
# * Check if hyperparameter tuning is enabled
#
#          - if yes:
#          Runs run_hyperparameter_tuning()
#          Picks the best hyperparameters.
#          Builds the best model with them.
#
#          - if no:
#          Builds a model with default hyperparameters.
#          Compiles it with Adam optimizer and categorical loss.
#
# * Set up callbacks for final training
# * Train the final model

# %%
def main_training_pipeline(use_hyperparameter_tuning=True, max_trials=20):

    # Calculate class weights
    # class_weights = calculate_class_weights(y_train)
    # print("Class weights:", class_weights)


    #If tuning enabled:
    if use_hyperparameter_tuning:
        print("\n" + "="*60)
        print("Running Hyperparameter Tuning")
        print("="*60)

        # Run hyperparameter tuning
        tuner, best_hps = run_hyperparameter_tuning(
            X_train, y_train, X_val, y_val, class_weights, max_trials
        )

        # Build best model
        print("\nBuilding best model with tuned hyperparameters...")
        model = tuner.hypermodel.build(best_hps)
        print("\nSuccessfully build the best model.")

        # Display best model summary
        print("\nBest model summary:")
        model.summary()


    #If tuning disabled:Creates model with default hyperparameters
    else:
        print("\n" + "="*60)
        print("Using default hyperparameters..")
        print("="*60)

        # Create model with default hyperparameters
        model = create_emotion_model(input_shape=(48, 48, 1), num_classes=len(TARGET_CLASSES))

        # Compile the model
        model.compile(
            optimizer=Adam(learning_rate=0.001),
            loss=SparseCategoricalCrossentropy(from_logits=False),
            metrics=[SparseCategoricalAccuracy(name='accuracy')]
        )

        print("Model summary:")
        model.summary()




    # Setup callbacks for final training
    callbacks = [

        #saves best model based on val_accuracy
        ModelCheckpoint(
            filepath=str(MODEL_SAVE_PATH / ('best_emotion_model_tuned.h5' if use_hyperparameter_tuning else 'best_emotion_model.h5')),
            monitor='val_accuracy',
            save_best_only=True,
            save_weights_only=False,
            mode='max',
            verbose=1
        ),

        #stops if no improvement (patience=15)
        EarlyStopping(
            monitor='val_accuracy',
            patience=15,  # Increased patience for final training
            restore_best_weights=True,
            verbose=1
        ),

        #reduces learning rate when stuck (patience=7)
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=7,
            min_lr=1e-7,
            verbose=1
        )
    ]

    # Train the final model
    print("\n" + "="*60)
    print("\nFinal Training.")
    print("="*60)
    print(f"Training samples: {len(X_train)}")
    print(f"Validation samples: {len(X_val)}")
    print(f"Batch size: {BATCH_SIZE}")

    history = model.fit(
        train_generator,
        epochs=EPOCHS,
        validation_data=val_generator,
        callbacks=callbacks,
        class_weight=class_weights,
        verbose=1
    )

    return model, history

# %% [markdown]
# ## **10. Model Evaluation & Testing**

# %% [markdown]
#     - Plot training and validation \metrics
#     - Comprehensive model evaluation

# %%
#Plot training metrics
def plot_training_history(history):

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
    ax1.set_title(f'Model Accuracy Over Time ({len(history.history["accuracy"])} epochs)')

    # Accuracy
    ax1.plot(history.history['accuracy'], label='Train')  #Plots training accuracy vs epochs.
    ax1.plot(history.history['val_accuracy'], label='Val') #Plots validation accuracy  vs epochs.
    ax1.set_title('Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.legend()
    ax1.grid(alpha=0.3)

    # Loss
    ax2.plot(history.history['loss'], label='Train')  #Plots training loss  vs epochs
    ax2.plot(history.history['val_loss'], label='Val') #Plots validation loss  vs epochs.
    ax2.set_title('Loss')
    ax2.set_xlabel('Epoch')
    ax2.legend()
    ax2.grid(alpha=0.3)

    plt.tight_layout()
    plt.show()

# %%
#Comprehensive model evaluation
def evaluate_model(model, X_test, y_test):

    print("\n" + "="*60)
    print("Model Evaluation")
    print("="*60)


    # Make Predictions
    y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

    #Compute weighted precision, recall, F1-score
    precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='weighted')
    print(f"\nWeighted Precision: {precision:.4f}")
    print(f"Weighted Recall: {recall:.4f}")
    print(f"Weighted F1-Score: {f1:.4f}")

    # Evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
    print(f"Test Accuracy: {test_acc:.4f} | Test Loss: {test_loss:.4f}")

    print("  ")
    # Classification report
    print("\n" + classification_report(y_test, y_pred, target_names=TARGET_CLASSES, digits=4))

    print("  ")
    # Confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=TARGET_CLASSES, yticklabels=TARGET_CLASSES)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.tight_layout()
    plt.show()

    print("  ")
    # Per-class accuracy
    print("\nPer-class accuracy:")
    for i, name in enumerate(TARGET_CLASSES):
        print(f"{name}: {cm[i,i]/cm[i].sum():.4f}")

    return test_acc, cm

# %% [markdown]
# ## **11. Prediction Function**

# %% [markdown]
#     - prepares a single image
#     - normalizes it
#     - predicts emotion
#     - returns the predicted label, its confidence, and all class probabilities

# %%
#Predict emotion from single image
def predict_emotion(model, image):

    # Prepare image
    if len(image.shape) == 2:  #Check image shape-If image is grayscale (2D), adds a channel dimension (H, W, 1).
        image = image[..., np.newaxis]
    image = np.expand_dims(image, 0)  #Adds batch dimension → shape becomes (1, H, W, C).
    if image.max() > 1.0:
        image = image.astype('float32') / 255.0  #f pixel values are 0–255, scales them to 0–1 range

    # Gets prediction probabilities for each class.
    preds = model.predict(image, verbose=0)[0]
    pred_class = np.argmax(preds)

    return TARGET_CLASSES[pred_class], preds[pred_class], preds

# %% [markdown]
# ## **12. Main execution script**

# %%
if __name__ == "__main__":

    # Choose whether to use hyperparameter tuning
    USE_TUNING = True  # Set to False for faster training with default parameters

    MAX_TRIALS = 5

    print("="*60)
    print("Emotion recognition model training Start..")
    print("="*60)
    print(f"Using hyperparameter tuning: {USE_TUNING}")
    if USE_TUNING:
        print(f"Max tuning trials: {MAX_TRIALS}")  # MAX_TRIALS=15 ,default =20

    print("\n" + "-"*60)
    # Run the complete training pipeline
    model, history = main_training_pipeline(
        use_hyperparameter_tuning=USE_TUNING,
        max_trials=MAX_TRIALS
    )

    print("\n" + "-"*60)
    # Plot training history
    print("\nPlotting training history...")
    plot_training_history(history)

    print("\n" + "-"*60)
    # Load best model and evaluate
    model_path = MODEL_SAVE_PATH / ('best_emotion_model_tuned.h5' if USE_TUNING else 'best_emotion_model.h5')
    print(f"\nLoading best model from {model_path}...")
    model = keras.models.load_model(str(model_path))


    # Comprehensive evaluation
    test_accuracy, cm = evaluate_model(model, X_test, y_test)

    print("\n" + "-"*60)
    # Test prediction function
    print("\nTesting prediction function:")
    sample_idx = 0
    sample_image = X_test[sample_idx]
    true_emotion = TARGET_CLASSES[y_test[sample_idx]]

    predicted_emotion, confidence, all_probs = predict_emotion(model, sample_image)

    print(f"True emotion: {true_emotion}")
    print(f"Predicted emotion: {predicted_emotion}")
    print(f"Confidence: {confidence:.4f}")

    print("\n" + "-"*60)
    # Save final model
    final_model_name = MODEL_SAVE_PATH / ('final_emotion_model_tuned.h5' if USE_TUNING else 'final_emotion_model.h5')
    print(f"\nSaving final model as {final_model_name}...")
    model.save(str(final_model_name))


    print("\n" + "="*60)
    print("TRAINING COMPLETE!")
    print("="*60)
    print(f"Final test accuracy: {test_accuracy:.4f}")
    print(f"Model saved as: {final_model_name}")
    print(f"Model parameters: {model.count_params():,}")
# Out:
# Trial 5 Complete [00h 04m 56s]
# val_accuracy: 0.25787079334259033
#
# Best val_accuracy So Far: 0.5282984375953674
# Total elapsed time: 00h 37m 06s
#
# ------------------------------------------------------------
#
# Best hyperparameters:
# learning_rate: 0.00012850284319400977
# stem_filters: 48
# top_filters: 1152
# se_ratio: 0.1
# mbconv_dropout: 0.1
# dense1_units: 256
# dense1_dropout: 0.3
#
# Building best model with tuned hyperparameters...
#
# Successfully build the best model.
#
# Best model summary:
# Model: "efficientnetb0_grayscale_tuned"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ grayscale_input     │ (None, 48, 48, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 24, 24,    │        432 │ grayscale_input[… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn             │ (None, 24, 24,    │        192 │ stem_conv[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_activation     │ (None, 24, 24,    │          0 │ stem_bn[0][0]     │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block0_dwconv       │ (None, 24, 24,    │        432 │ stem_activation[… │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block0_bn           │ (None, 24, 24,    │        192 │ block0_dwconv[0]… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block0_activation   │ (None, 24, 24,    │          0 │ block0_bn[0][0]   │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block0_se_squeeze   │ (None, 48)        │          0 │ block0_activatio… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block0_se_reshape   │ (None, 1, 1, 48)  │          0 │ block0_se_squeez… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block0_se_reduce    │ (None, 1, 1, 4)   │        196 │ block0_se_reshap… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block0_se_expand    │ (None, 1, 1, 48)  │        240 │ block0_se_reduce… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block0_se_excite    │ (None, 24, 24,    │          0 │ block0_activatio… │
# │ (Multiply)          │ 48)               │            │ block0_se_expand… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block0_dropout      │ (None, 24, 24,    │          0 │ block0_se_excite… │
# │ (Dropout)           │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block0_project_conv │ (None, 24, 24,    │        768 │ block0_dropout[0… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block0_project_bn   │ (None, 24, 24,    │         64 │ block0_project_c… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_expand_conv  │ (None, 24, 24,    │      1,536 │ block0_project_b… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_expand_bn    │ (None, 24, 24,    │        384 │ block1_expand_co… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_expand_acti… │ (None, 24, 24,    │          0 │ block1_expand_bn… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_dwconv       │ (None, 12, 12,    │        864 │ block1_expand_ac… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_bn           │ (None, 12, 12,    │        384 │ block1_dwconv[0]… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_activation   │ (None, 12, 12,    │          0 │ block1_bn[0][0]   │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_se_squeeze   │ (None, 96)        │          0 │ block1_activatio… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_se_reshape   │ (None, 1, 1, 96)  │          0 │ block1_se_squeez… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_se_reduce    │ (None, 1, 1, 1)   │         97 │ block1_se_reshap… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_se_expand    │ (None, 1, 1, 96)  │        192 │ block1_se_reduce… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_se_excite    │ (None, 12, 12,    │          0 │ block1_activatio… │
# │ (Multiply)          │ 96)               │            │ block1_se_expand… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_dropout      │ (None, 12, 12,    │          0 │ block1_se_excite… │
# │ (Dropout)           │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_project_conv │ (None, 12, 12,    │      2,304 │ block1_dropout[0… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_project_bn   │ (None, 12, 12,    │         96 │ block1_project_c… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_expand_conv  │ (None, 12, 12,    │      3,456 │ block1_project_b… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_expand_bn    │ (None, 12, 12,    │        576 │ block2_expand_co… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_expand_acti… │ (None, 12, 12,    │          0 │ block2_expand_bn… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_dwconv       │ (None, 12, 12,    │      1,296 │ block2_expand_ac… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_bn           │ (None, 12, 12,    │        576 │ block2_dwconv[0]… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_activation   │ (None, 12, 12,    │          0 │ block2_bn[0][0]   │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_se_squeeze   │ (None, 144)       │          0 │ block2_activatio… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_se_reshape   │ (None, 1, 1, 144) │          0 │ block2_se_squeez… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_se_reduce    │ (None, 1, 1, 2)   │        290 │ block2_se_reshap… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_se_expand    │ (None, 1, 1, 144) │        432 │ block2_se_reduce… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_se_excite    │ (None, 12, 12,    │          0 │ block2_activatio… │
# │ (Multiply)          │ 144)              │            │ block2_se_expand… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_dropout      │ (None, 12, 12,    │          0 │ block2_se_excite… │
# │ (Dropout)           │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_project_conv │ (None, 12, 12,    │      3,456 │ block2_dropout[0… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_project_bn   │ (None, 12, 12,    │         96 │ block2_project_c… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_add (Add)    │ (None, 12, 12,    │          0 │ block1_project_b… │
# │                     │ 24)               │            │ block2_project_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_expand_conv  │ (None, 12, 12,    │      3,456 │ block2_add[0][0]  │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_expand_bn    │ (None, 12, 12,    │        576 │ block3_expand_co… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_expand_acti… │ (None, 12, 12,    │          0 │ block3_expand_bn… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_dwconv       │ (None, 6, 6, 144) │      3,600 │ block3_expand_ac… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_bn           │ (None, 6, 6, 144) │        576 │ block3_dwconv[0]… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_activation   │ (None, 6, 6, 144) │          0 │ block3_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_se_squeeze   │ (None, 144)       │          0 │ block3_activatio… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_se_reshape   │ (None, 1, 1, 144) │          0 │ block3_se_squeez… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_se_reduce    │ (None, 1, 1, 2)   │        290 │ block3_se_reshap… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_se_expand    │ (None, 1, 1, 144) │        432 │ block3_se_reduce… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_se_excite    │ (None, 6, 6, 144) │          0 │ block3_activatio… │
# │ (Multiply)          │                   │            │ block3_se_expand… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_dropout      │ (None, 6, 6, 144) │          0 │ block3_se_excite… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_project_conv │ (None, 6, 6, 40)  │      5,760 │ block3_dropout[0… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_project_bn   │ (None, 6, 6, 40)  │        160 │ block3_project_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_expand_conv  │ (None, 6, 6, 240) │      9,600 │ block3_project_b… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_expand_bn    │ (None, 6, 6, 240) │        960 │ block4_expand_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_expand_acti… │ (None, 6, 6, 240) │          0 │ block4_expand_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_dwconv       │ (None, 6, 6, 240) │      6,000 │ block4_expand_ac… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_bn           │ (None, 6, 6, 240) │        960 │ block4_dwconv[0]… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_activation   │ (None, 6, 6, 240) │          0 │ block4_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_se_squeeze   │ (None, 240)       │          0 │ block4_activatio… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_se_reshape   │ (None, 1, 1, 240) │          0 │ block4_se_squeez… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_se_reduce    │ (None, 1, 1, 4)   │        964 │ block4_se_reshap… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_se_expand    │ (None, 1, 1, 240) │      1,200 │ block4_se_reduce… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_se_excite    │ (None, 6, 6, 240) │          0 │ block4_activatio… │
# │ (Multiply)          │                   │            │ block4_se_expand… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_dropout      │ (None, 6, 6, 240) │          0 │ block4_se_excite… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_project_conv │ (None, 6, 6, 40)  │      9,600 │ block4_dropout[0… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_project_bn   │ (None, 6, 6, 40)  │        160 │ block4_project_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_add (Add)    │ (None, 6, 6, 40)  │          0 │ block3_project_b… │
# │                     │                   │            │ block4_project_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_expand_conv  │ (None, 6, 6, 240) │      9,600 │ block4_add[0][0]  │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_expand_bn    │ (None, 6, 6, 240) │        960 │ block5_expand_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_expand_acti… │ (None, 6, 6, 240) │          0 │ block5_expand_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_dwconv       │ (None, 3, 3, 240) │      2,160 │ block5_expand_ac… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_bn           │ (None, 3, 3, 240) │        960 │ block5_dwconv[0]… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_activation   │ (None, 3, 3, 240) │          0 │ block5_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_se_squeeze   │ (None, 240)       │          0 │ block5_activatio… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_se_reshape   │ (None, 1, 1, 240) │          0 │ block5_se_squeez… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_se_reduce    │ (None, 1, 1, 4)   │        964 │ block5_se_reshap… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_se_expand    │ (None, 1, 1, 240) │      1,200 │ block5_se_reduce… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_se_excite    │ (None, 3, 3, 240) │          0 │ block5_activatio… │
# │ (Multiply)          │                   │            │ block5_se_expand… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_dropout      │ (None, 3, 3, 240) │          0 │ block5_se_excite… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_project_conv │ (None, 3, 3, 80)  │     19,200 │ block5_dropout[0… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_project_bn   │ (None, 3, 3, 80)  │        320 │ block5_project_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_expand_conv  │ (None, 3, 3, 480) │     38,400 │ block5_project_b… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_expand_bn    │ (None, 3, 3, 480) │      1,920 │ block6_expand_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_expand_acti… │ (None, 3, 3, 480) │          0 │ block6_expand_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_dwconv       │ (None, 3, 3, 480) │      4,320 │ block6_expand_ac… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_bn           │ (None, 3, 3, 480) │      1,920 │ block6_dwconv[0]… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_activation   │ (None, 3, 3, 480) │          0 │ block6_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_se_squeeze   │ (None, 480)       │          0 │ block6_activatio… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_se_reshape   │ (None, 1, 1, 480) │          0 │ block6_se_squeez… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_se_reduce    │ (None, 1, 1, 8)   │      3,848 │ block6_se_reshap… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_se_expand    │ (None, 1, 1, 480) │      4,320 │ block6_se_reduce… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_se_excite    │ (None, 3, 3, 480) │          0 │ block6_activatio… │
# │ (Multiply)          │                   │            │ block6_se_expand… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_dropout      │ (None, 3, 3, 480) │          0 │ block6_se_excite… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_project_conv │ (None, 3, 3, 80)  │     38,400 │ block6_dropout[0… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_project_bn   │ (None, 3, 3, 80)  │        320 │ block6_project_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_add (Add)    │ (None, 3, 3, 80)  │          0 │ block5_project_b… │
# │                     │                   │            │ block6_project_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_expand_conv  │ (None, 3, 3, 480) │     38,400 │ block6_add[0][0]  │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_expand_bn    │ (None, 3, 3, 480) │      1,920 │ block7_expand_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_expand_acti… │ (None, 3, 3, 480) │          0 │ block7_expand_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_dwconv       │ (None, 3, 3, 480) │      4,320 │ block7_expand_ac… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_bn           │ (None, 3, 3, 480) │      1,920 │ block7_dwconv[0]… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_activation   │ (None, 3, 3, 480) │          0 │ block7_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_se_squeeze   │ (None, 480)       │          0 │ block7_activatio… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_se_reshape   │ (None, 1, 1, 480) │          0 │ block7_se_squeez… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_se_reduce    │ (None, 1, 1, 8)   │      3,848 │ block7_se_reshap… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_se_expand    │ (None, 1, 1, 480) │      4,320 │ block7_se_reduce… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_se_excite    │ (None, 3, 3, 480) │          0 │ block7_activatio… │
# │ (Multiply)          │                   │            │ block7_se_expand… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_dropout      │ (None, 3, 3, 480) │          0 │ block7_se_excite… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_project_conv │ (None, 3, 3, 80)  │     38,400 │ block7_dropout[0… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_project_bn   │ (None, 3, 3, 80)  │        320 │ block7_project_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_add (Add)    │ (None, 3, 3, 80)  │          0 │ block6_add[0][0], │
# │                     │                   │            │ block7_project_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_expand_conv  │ (None, 3, 3, 480) │     38,400 │ block7_add[0][0]  │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_expand_bn    │ (None, 3, 3, 480) │      1,920 │ block8_expand_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_expand_acti… │ (None, 3, 3, 480) │          0 │ block8_expand_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_dwconv       │ (None, 3, 3, 480) │     12,000 │ block8_expand_ac… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_bn           │ (None, 3, 3, 480) │      1,920 │ block8_dwconv[0]… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_activation   │ (None, 3, 3, 480) │          0 │ block8_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_se_squeeze   │ (None, 480)       │          0 │ block8_activatio… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_se_reshape   │ (None, 1, 1, 480) │          0 │ block8_se_squeez… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_se_reduce    │ (None, 1, 1, 8)   │      3,848 │ block8_se_reshap… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_se_expand    │ (None, 1, 1, 480) │      4,320 │ block8_se_reduce… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_se_excite    │ (None, 3, 3, 480) │          0 │ block8_activatio… │
# │ (Multiply)          │                   │            │ block8_se_expand… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_dropout      │ (None, 3, 3, 480) │          0 │ block8_se_excite… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_project_conv │ (None, 3, 3, 112) │     53,760 │ block8_dropout[0… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_project_bn   │ (None, 3, 3, 112) │        448 │ block8_project_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_expand_conv  │ (None, 3, 3, 672) │     75,264 │ block8_project_b… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_expand_bn    │ (None, 3, 3, 672) │      2,688 │ block9_expand_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_expand_acti… │ (None, 3, 3, 672) │          0 │ block9_expand_bn… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_dwconv       │ (None, 3, 3, 672) │     16,800 │ block9_expand_ac… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_bn           │ (None, 3, 3, 672) │      2,688 │ block9_dwconv[0]… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_activation   │ (None, 3, 3, 672) │          0 │ block9_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_se_squeeze   │ (None, 672)       │          0 │ block9_activatio… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_se_reshape   │ (None, 1, 1, 672) │          0 │ block9_se_squeez… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_se_reduce    │ (None, 1, 1, 11)  │      7,403 │ block9_se_reshap… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_se_expand    │ (None, 1, 1, 672) │      8,064 │ block9_se_reduce… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_se_excite    │ (None, 3, 3, 672) │          0 │ block9_activatio… │
# │ (Multiply)          │                   │            │ block9_se_expand… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_dropout      │ (None, 3, 3, 672) │          0 │ block9_se_excite… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_project_conv │ (None, 3, 3, 112) │     75,264 │ block9_dropout[0… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_project_bn   │ (None, 3, 3, 112) │        448 │ block9_project_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_add (Add)    │ (None, 3, 3, 112) │          0 │ block8_project_b… │
# │                     │                   │            │ block9_project_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_expand_conv │ (None, 3, 3, 672) │     75,264 │ block9_add[0][0]  │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_expand_bn   │ (None, 3, 3, 672) │      2,688 │ block10_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_expand_act… │ (None, 3, 3, 672) │          0 │ block10_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_dwconv      │ (None, 3, 3, 672) │     16,800 │ block10_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_bn          │ (None, 3, 3, 672) │      2,688 │ block10_dwconv[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_activation  │ (None, 3, 3, 672) │          0 │ block10_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_se_squeeze  │ (None, 672)       │          0 │ block10_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_se_reshape  │ (None, 1, 1, 672) │          0 │ block10_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_se_reduce   │ (None, 1, 1, 11)  │      7,403 │ block10_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_se_expand   │ (None, 1, 1, 672) │      8,064 │ block10_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_se_excite   │ (None, 3, 3, 672) │          0 │ block10_activati… │
# │ (Multiply)          │                   │            │ block10_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_dropout     │ (None, 3, 3, 672) │          0 │ block10_se_excit… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_project_co… │ (None, 3, 3, 112) │     75,264 │ block10_dropout[… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_project_bn  │ (None, 3, 3, 112) │        448 │ block10_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_add (Add)   │ (None, 3, 3, 112) │          0 │ block9_add[0][0], │
# │                     │                   │            │ block10_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_expand_conv │ (None, 3, 3, 672) │     75,264 │ block10_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_expand_bn   │ (None, 3, 3, 672) │      2,688 │ block11_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_expand_act… │ (None, 3, 3, 672) │          0 │ block11_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_dwconv      │ (None, 2, 2, 672) │     16,800 │ block11_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_bn          │ (None, 2, 2, 672) │      2,688 │ block11_dwconv[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_activation  │ (None, 2, 2, 672) │          0 │ block11_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_se_squeeze  │ (None, 672)       │          0 │ block11_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_se_reshape  │ (None, 1, 1, 672) │          0 │ block11_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_se_reduce   │ (None, 1, 1, 11)  │      7,403 │ block11_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_se_expand   │ (None, 1, 1, 672) │      8,064 │ block11_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_se_excite   │ (None, 2, 2, 672) │          0 │ block11_activati… │
# │ (Multiply)          │                   │            │ block11_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_dropout     │ (None, 2, 2, 672) │          0 │ block11_se_excit… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_project_co… │ (None, 2, 2, 192) │    129,024 │ block11_dropout[… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_project_bn  │ (None, 2, 2, 192) │        768 │ block11_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_expand_conv │ (None, 2, 2,      │    221,184 │ block11_project_… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_expand_bn   │ (None, 2, 2,      │      4,608 │ block12_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_expand_act… │ (None, 2, 2,      │          0 │ block12_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_dwconv      │ (None, 2, 2,      │     28,800 │ block12_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_bn          │ (None, 2, 2,      │      4,608 │ block12_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_activation  │ (None, 2, 2,      │          0 │ block12_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_se_squeeze  │ (None, 1152)      │          0 │ block12_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_se_reshape  │ (None, 1, 1,      │          0 │ block12_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_se_reduce   │ (None, 1, 1, 19)  │     21,907 │ block12_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_se_expand   │ (None, 1, 1,      │     23,040 │ block12_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_se_excite   │ (None, 2, 2,      │          0 │ block12_activati… │
# │ (Multiply)          │ 1152)             │            │ block12_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_dropout     │ (None, 2, 2,      │          0 │ block12_se_excit… │
# │ (Dropout)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_project_co… │ (None, 2, 2, 192) │    221,184 │ block12_dropout[… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_project_bn  │ (None, 2, 2, 192) │        768 │ block12_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_add (Add)   │ (None, 2, 2, 192) │          0 │ block11_project_… │
# │                     │                   │            │ block12_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_expand_conv │ (None, 2, 2,      │    221,184 │ block12_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_expand_bn   │ (None, 2, 2,      │      4,608 │ block13_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_expand_act… │ (None, 2, 2,      │          0 │ block13_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_dwconv      │ (None, 2, 2,      │     28,800 │ block13_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_bn          │ (None, 2, 2,      │      4,608 │ block13_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_activation  │ (None, 2, 2,      │          0 │ block13_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_se_squeeze  │ (None, 1152)      │          0 │ block13_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_se_reshape  │ (None, 1, 1,      │          0 │ block13_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_se_reduce   │ (None, 1, 1, 19)  │     21,907 │ block13_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_se_expand   │ (None, 1, 1,      │     23,040 │ block13_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_se_excite   │ (None, 2, 2,      │          0 │ block13_activati… │
# │ (Multiply)          │ 1152)             │            │ block13_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_dropout     │ (None, 2, 2,      │          0 │ block13_se_excit… │
# │ (Dropout)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_project_co… │ (None, 2, 2, 192) │    221,184 │ block13_dropout[… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_project_bn  │ (None, 2, 2, 192) │        768 │ block13_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_add (Add)   │ (None, 2, 2, 192) │          0 │ block12_add[0][0… │
# ...
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.2834 - loss: 1.5836 - val_accuracy: 0.3161 - val_loss: 1.5718 - learning_rate: 1.2850e-04
# Epoch 8/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3091 - loss: 1.5722
# Epoch 8: val_accuracy improved from 0.31920 to 0.36087, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 22s 25ms/step - accuracy: 0.3091 - loss: 1.5722 - val_accuracy: 0.3609 - val_loss: 1.5118 - learning_rate: 1.2850e-04
# Epoch 9/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3174 - loss: 1.5631
# Epoch 9: val_accuracy improved from 0.36087 to 0.36979, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.3174 - loss: 1.5631 - val_accuracy: 0.3698 - val_loss: 1.4951 - learning_rate: 1.2850e-04
# Epoch 10/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3246 - loss: 1.5476
# Epoch 10: val_accuracy improved from 0.36979 to 0.39527, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 22s 25ms/step - accuracy: 0.3246 - loss: 1.5476 - val_accuracy: 0.3953 - val_loss: 1.4573 - learning_rate: 1.2850e-04
# Epoch 11/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3501 - loss: 1.5321
# Epoch 11: val_accuracy improved from 0.39527 to 0.39691, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 22s 25ms/step - accuracy: 0.3501 - loss: 1.5321 - val_accuracy: 0.3969 - val_loss: 1.4519 - learning_rate: 1.2850e-04
# Epoch 12/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3522 - loss: 1.5245
# Epoch 12: val_accuracy improved from 0.39691 to 0.40218, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 22s 25ms/step - accuracy: 0.3522 - loss: 1.5245 - val_accuracy: 0.4022 - val_loss: 1.4195 - learning_rate: 1.2850e-04
# Epoch 13/50
# 877/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3715 - loss: 1.5034
# Epoch 13: val_accuracy improved from 0.40218 to 0.41092, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 22s 25ms/step - accuracy: 0.3715 - loss: 1.5034 - val_accuracy: 0.4109 - val_loss: 1.4433 - learning_rate: 1.2850e-04
# Epoch 14/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3713 - loss: 1.4973
# Epoch 14: val_accuracy improved from 0.41092 to 0.41256, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 22s 25ms/step - accuracy: 0.3713 - loss: 1.4973 - val_accuracy: 0.4126 - val_loss: 1.3851 - learning_rate: 1.2850e-04
# Epoch 15/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3818 - loss: 1.4802
# Epoch 15: val_accuracy improved from 0.41256 to 0.44495, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.3818 - loss: 1.4802 - val_accuracy: 0.4449 - val_loss: 1.3508 - learning_rate: 1.2850e-04
# Epoch 16/50
# 877/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3829 - loss: 1.4793
# Epoch 16: val_accuracy did not improve from 0.44495
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - accuracy: 0.3829 - loss: 1.4793 - val_accuracy: 0.4369 - val_loss: 1.3476 - learning_rate: 1.2850e-04
# Epoch 17/50
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4019 - loss: 1.4567
# Epoch 17: val_accuracy improved from 0.44495 to 0.44950, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 22s 25ms/step - accuracy: 0.4019 - loss: 1.4567 - val_accuracy: 0.4495 - val_loss: 1.3337 - learning_rate: 1.2850e-04
# Epoch 18/50
# 877/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4096 - loss: 1.4424
# Epoch 18: val_accuracy improved from 0.44950 to 0.45478, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4096 - loss: 1.4424 - val_accuracy: 0.4548 - val_loss: 1.3056 - learning_rate: 1.2850e-04
# Epoch 19/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4098 - loss: 1.4417
# Epoch 19: val_accuracy improved from 0.45478 to 0.45823, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 22s 25ms/step - accuracy: 0.4099 - loss: 1.4417 - val_accuracy: 0.4582 - val_loss: 1.3068 - learning_rate: 1.2850e-04
# Epoch 20/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4176 - loss: 1.4317
# Epoch 20: val_accuracy improved from 0.45823 to 0.46187, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4176 - loss: 1.4317 - val_accuracy: 0.4619 - val_loss: 1.3066 - learning_rate: 1.2850e-04
# Epoch 21/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4255 - loss: 1.4131
# Epoch 21: val_accuracy improved from 0.46187 to 0.46479, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4255 - loss: 1.4131 - val_accuracy: 0.4648 - val_loss: 1.2846 - learning_rate: 1.2850e-04
# Epoch 22/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4241 - loss: 1.4104
# Epoch 22: val_accuracy improved from 0.46479 to 0.47680, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 22s 24ms/step - accuracy: 0.4241 - loss: 1.4104 - val_accuracy: 0.4768 - val_loss: 1.2705 - learning_rate: 1.2850e-04
# Epoch 23/50
# 877/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4291 - loss: 1.4006
# Epoch 23: val_accuracy improved from 0.47680 to 0.47934, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4291 - loss: 1.4006 - val_accuracy: 0.4793 - val_loss: 1.2661 - learning_rate: 1.2850e-04
# Epoch 24/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4325 - loss: 1.3873
# Epoch 24: val_accuracy did not improve from 0.47934
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4325 - loss: 1.3873 - val_accuracy: 0.4710 - val_loss: 1.2915 - learning_rate: 1.2850e-04
# Epoch 25/50
# 877/879 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4276 - loss: 1.3863
# Epoch 25: val_accuracy improved from 0.47934 to 0.48353, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4276 - loss: 1.3863 - val_accuracy: 0.4835 - val_loss: 1.2473 - learning_rate: 1.2850e-04
# Epoch 26/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4375 - loss: 1.3783
# Epoch 26: val_accuracy did not improve from 0.48353
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4375 - loss: 1.3783 - val_accuracy: 0.4803 - val_loss: 1.2446 - learning_rate: 1.2850e-04
# Epoch 27/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4384 - loss: 1.3727
# Epoch 27: val_accuracy improved from 0.48353 to 0.48444, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4384 - loss: 1.3727 - val_accuracy: 0.4844 - val_loss: 1.2375 - learning_rate: 1.2850e-04
# Epoch 28/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4483 - loss: 1.3563
# Epoch 28: val_accuracy did not improve from 0.48444
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.4483 - loss: 1.3563 - val_accuracy: 0.3925 - val_loss: 1.4429 - learning_rate: 1.2850e-04
# Epoch 29/50
# 877/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4362 - loss: 1.3854
# Epoch 29: val_accuracy improved from 0.48444 to 0.48681, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 22s 25ms/step - accuracy: 0.4362 - loss: 1.3854 - val_accuracy: 0.4868 - val_loss: 1.2322 - learning_rate: 1.2850e-04
# Epoch 30/50
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4412 - loss: 1.3718
# Epoch 30: val_accuracy did not improve from 0.48681
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.4412 - loss: 1.3718 - val_accuracy: 0.4832 - val_loss: 1.2665 - learning_rate: 1.2850e-04
# Epoch 31/50
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4326 - loss: 1.3896
# Epoch 31: val_accuracy improved from 0.48681 to 0.49827, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4326 - loss: 1.3896 - val_accuracy: 0.4983 - val_loss: 1.2324 - learning_rate: 1.2850e-04
# Epoch 32/50
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4496 - loss: 1.3627
# Epoch 32: val_accuracy improved from 0.49827 to 0.50373, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4496 - loss: 1.3626 - val_accuracy: 0.5037 - val_loss: 1.2194 - learning_rate: 1.2850e-04
# Epoch 33/50
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4623 - loss: 1.3400
# Epoch 33: val_accuracy improved from 0.50373 to 0.50446, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4622 - loss: 1.3400 - val_accuracy: 0.5045 - val_loss: 1.2023 - learning_rate: 1.2850e-04
# Epoch 34/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4556 - loss: 1.3429
# Epoch 34: val_accuracy improved from 0.50446 to 0.50755, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - accuracy: 0.4556 - loss: 1.3429 - val_accuracy: 0.5076 - val_loss: 1.2025 - learning_rate: 1.2850e-04
# Epoch 35/50
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4607 - loss: 1.3430
# Epoch 35: val_accuracy improved from 0.50755 to 0.50937, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4607 - loss: 1.3431 - val_accuracy: 0.5094 - val_loss: 1.2019 - learning_rate: 1.2850e-04
# Epoch 36/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4521 - loss: 1.3583
# Epoch 36: val_accuracy did not improve from 0.50937
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - accuracy: 0.4521 - loss: 1.3583 - val_accuracy: 0.5052 - val_loss: 1.2317 - learning_rate: 1.2850e-04
# Epoch 37/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4555 - loss: 1.3509
# Epoch 37: val_accuracy did not improve from 0.50937
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - accuracy: 0.4555 - loss: 1.3509 - val_accuracy: 0.5021 - val_loss: 1.2228 - learning_rate: 1.2850e-04
# Epoch 38/50
# 877/879 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4476 - loss: 1.3608
# Epoch 38: val_accuracy did not improve from 0.50937
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - accuracy: 0.4476 - loss: 1.3608 - val_accuracy: 0.4939 - val_loss: 1.2200 - learning_rate: 1.2850e-04
# Epoch 39/50
# 877/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4624 - loss: 1.3445
# Epoch 39: val_accuracy improved from 0.50937 to 0.51301, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4624 - loss: 1.3445 - val_accuracy: 0.5130 - val_loss: 1.2010 - learning_rate: 1.2850e-04
# Epoch 40/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4618 - loss: 1.3472
# Epoch 40: val_accuracy did not improve from 0.51301
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.4618 - loss: 1.3472 - val_accuracy: 0.5092 - val_loss: 1.2023 - learning_rate: 1.2850e-04
# Epoch 41/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4567 - loss: 1.3326
# Epoch 41: val_accuracy improved from 0.51301 to 0.51374, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4567 - loss: 1.3326 - val_accuracy: 0.5137 - val_loss: 1.1825 - learning_rate: 1.2850e-04
# Epoch 42/50
# 877/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4652 - loss: 1.3278
# Epoch 42: val_accuracy did not improve from 0.51374
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4652 - loss: 1.3278 - val_accuracy: 0.4843 - val_loss: 1.2539 - learning_rate: 1.2850e-04
# Epoch 43/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4499 - loss: 1.3516
# Epoch 43: val_accuracy did not improve from 0.51374
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - accuracy: 0.4499 - loss: 1.3516 - val_accuracy: 0.4795 - val_loss: 1.2465 - learning_rate: 1.2850e-04
# Epoch 44/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4581 - loss: 1.3341
# Epoch 44: val_accuracy improved from 0.51374 to 0.51429, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4581 - loss: 1.3341 - val_accuracy: 0.5143 - val_loss: 1.1807 - learning_rate: 1.2850e-04
# Epoch 45/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4719 - loss: 1.3169
# Epoch 45: val_accuracy did not improve from 0.51429
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - accuracy: 0.4719 - loss: 1.3169 - val_accuracy: 0.5081 - val_loss: 1.1858 - learning_rate: 1.2850e-04
# Epoch 46/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4570 - loss: 1.3335
# Epoch 46: val_accuracy improved from 0.51429 to 0.51556, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4570 - loss: 1.3335 - val_accuracy: 0.5156 - val_loss: 1.1704 - learning_rate: 1.2850e-04
# Epoch 47/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4725 - loss: 1.3174
# Epoch 47: val_accuracy did not improve from 0.51556
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4725 - loss: 1.3174 - val_accuracy: 0.5121 - val_loss: 1.1815 - learning_rate: 1.2850e-04
# Epoch 48/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4702 - loss: 1.3117
# Epoch 48: val_accuracy improved from 0.51556 to 0.52011, saving model to /kaggle/working/best_emotion_model_tuned.h5
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4702 - loss: 1.3117 - val_accuracy: 0.5201 - val_loss: 1.1809 - learning_rate: 1.2850e-04
# Epoch 49/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4677 - loss: 1.3243
# Epoch 49: val_accuracy did not improve from 0.52011
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.4677 - loss: 1.3243 - val_accuracy: 0.5056 - val_loss: 1.1929 - learning_rate: 1.2850e-04
# Epoch 50/50
# 878/879 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4743 - loss: 1.3123
# Epoch 50: val_accuracy did not improve from 0.52011
# 879/879 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - accuracy: 0.4743 - loss: 1.3123 - val_accuracy: 0.5157 - val_loss: 1.4032 - learning_rate: 1.2850e-04
# Restoring model weights from the end of the best epoch: 48.
#
# ------------------------------------------------------------
#
# Plotting training history...
# ------------------------------------------------------------
#
# Loading best model from /kaggle/working/best_emotion_model_tuned.h5...
#
# ============================================================
# Model Evaluation
# ============================================================
#
# Weighted Precision: 0.5345
# Weighted Recall: 0.5231
# Weighted F1-Score: 0.5201
# Test Accuracy: 0.5231 | Test Loss: 1.1727
#
#
#               precision    recall  f1-score   support
#
#        angry     0.3734    0.4531    0.4094      1055
#        happy     0.7068    0.7340    0.7202      1767
#          sad     0.3621    0.2264    0.2786      1241
#     stressed     0.6747    0.5266    0.5915      1804
#      neutral     0.3926    0.5747    0.4665      1225
#
#     accuracy                         0.5231      7092
#    macro avg     0.5019    0.5030    0.4933      7092
# weighted avg     0.5345    0.5231    0.5201      7092
#
#
# Per-class accuracy:
# angry: 0.4531
# happy: 0.7340
# sad: 0.2264
# stressed: 0.5266
# neutral: 0.5747
#
# ------------------------------------------------------------
#
# Testing prediction function:
# True emotion: angry
# Predicted emotion: happy
# Confidence: 0.4158
#
# ------------------------------------------------------------
#
# Saving final model as /kaggle/working/final_emotion_model_tuned.h5...
#
# ============================================================
# TRAINING COMPLETE!
# ============================================================
# Final test accuracy: 0.5231
# Model saved as: /kaggle/working/final_emotion_model_tuned.h5
# Model parameters: 4,072,619
