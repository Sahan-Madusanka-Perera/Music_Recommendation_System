# %% [markdown]
# ## Imports and Setups

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, SeparableConv2D, BatchNormalization
from tensorflow.keras.layers import Activation, GlobalAveragePooling2D, Dropout, Add, MaxPooling2D, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# ## Loading preprocessed data from '../../data/processed/FC211012_Azeem' path

# %%
# Define image size and batch size
IMG_SIZE = (48, 48)
BATCH_SIZE = 32

# Define paths
train_dir = '../../data/processed/FC211012_Azeem/train'
test_dir = '../../data/processed/FC211012_Azeem/test'

# Data augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1./255,           # Normalize pixels [0,1]
    rotation_range=15,        # Random rotate ±15 degrees
    zoom_range=0.1,           # Zoom in/out by ±10%
    horizontal_flip=True,     # Flip images horizontally
    fill_mode='nearest'       # Fill in new pixels
)

test_datagen = ImageDataGenerator(rescale=1./255)

# Load training data
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    color_mode='grayscale',
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Load testing/validation data
val_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=IMG_SIZE,
    color_mode='grayscale',
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 24612 images belonging to 5 classes.
# Found 6154 images belonging to 5 classes.

# %% [markdown]
# ## Defining Mini-Xception architecture for 5 Emotion classes

# %%
def Mini_XCEPTION(input_shape=(48, 48, 1), num_classes=5):
    input_layer = Input(shape=input_shape)

    # Initial Conv layer
    x = Conv2D(32, (3, 3), padding='same')(input_layer)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Residual Modules
    for filters in [64, 128, 256]:

        residual = Conv2D(filters, (1, 1), strides=(2, 2), padding='same')(x)
        residual = BatchNormalization()(residual)

        # Separable conv block
        x = SeparableConv2D(filters, (3, 3), padding='same')(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)

        x = SeparableConv2D(filters, (3, 3), padding='same')(x)
        x = BatchNormalization()(x)

        x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

        x = Add()([x, residual])

    # Final classification layers
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)
    output_layer = Dense(num_classes, activation='softmax')(x)

    return Model(input_layer, output_layer)


# Build the model
model = Mini_XCEPTION(input_shape=(48, 48, 1), num_classes=5)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]          0         []
#
#  conv2d (Conv2D)             (None, 48, 48, 32)           320       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 48, 48, 32)           128       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 48, 48, 32)           0         ['batch_normalization[0][0]']
#
#  separable_conv2d (Separabl  (None, 48, 48, 64)           2400      ['activation[0][0]']
#  eConv2D)
#
#  batch_normalization_2 (Bat  (None, 48, 48, 64)           256       ['separable_conv2d[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 48, 48, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  separable_conv2d_1 (Separa  (None, 48, 48, 64)           4736      ['activation_1[0][0]']
#  bleConv2D)
#
#  batch_normalization_3 (Bat  (None, 48, 48, 64)           256       ['separable_conv2d_1[0][0]']
#  chNormalization)
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)           2112      ['activation[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 64)           0         ['batch_normalization_3[0][0]'
#  D)                                                                 ]
#
#  batch_normalization_1 (Bat  (None, 24, 24, 64)           256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 24, 24, 64)           0         ['max_pooling2d[0][0]',
#                                                                      'batch_normalization_1[0][0]'
#                                                                     ]
#
#  separable_conv2d_2 (Separa  (None, 24, 24, 128)          8896      ['add[0][0]']
#  bleConv2D)
#
#  batch_normalization_5 (Bat  (None, 24, 24, 128)          512       ['separable_conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 24, 24, 128)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  separable_conv2d_3 (Separa  (None, 24, 24, 128)          17664     ['activation_2[0][0]']
#  bleConv2D)
#
#  batch_normalization_6 (Bat  (None, 24, 24, 128)          512       ['separable_conv2d_3[0][0]']
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 128)          8320      ['add[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 128)          0         ['batch_normalization_6[0][0]'
#  g2D)                                                               ]
#
#  batch_normalization_4 (Bat  (None, 12, 12, 128)          512       ['conv2d_2[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 12, 12, 128)          0         ['max_pooling2d_1[0][0]',
#                                                                      'batch_normalization_4[0][0]'
#                                                                     ]
#
#  separable_conv2d_4 (Separa  (None, 12, 12, 256)          34176     ['add_1[0][0]']
#  bleConv2D)
#
#  batch_normalization_8 (Bat  (None, 12, 12, 256)          1024      ['separable_conv2d_4[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 12, 12, 256)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  separable_conv2d_5 (Separa  (None, 12, 12, 256)          68096     ['activation_3[0][0]']
#  bleConv2D)
#
#  batch_normalization_9 (Bat  (None, 12, 12, 256)          1024      ['separable_conv2d_5[0][0]']
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 256)            33024     ['add_1[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 256)            0         ['batch_normalization_9[0][0]'
#  g2D)                                                               ]
#
#  batch_normalization_7 (Bat  (None, 6, 6, 256)            1024      ['conv2d_3[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 6, 6, 256)            0         ['max_pooling2d_2[0][0]',
#                                                                      'batch_normalization_7[0][0]'
#                                                                     ]
#
#  global_average_pooling2d (  (None, 256)                  0         ['add_2[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 256)                  0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 5)                    1285      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 186533 (728.64 KB)
# Trainable params: 183781 (717.89 KB)
# Non-trainable params: 2752 (10.75 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Compiling and training the model with Adam, EarlyStopping, and ModelCheckpoint

# %%
# Compil the model
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Define callbacks
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

checkpoint = ModelCheckpoint(
    filepath='../../models/FC211012_Azeem/emotion_detection_model.h5',
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

# Train the model
history = model.fit(
    train_generator,
    epochs=30,
    validation_data=val_generator,
    callbacks=[early_stop, checkpoint]
)
# Out:
# Epoch 1/30
# 770/770 [==============================] - ETA: 0s - loss: 1.5719 - accuracy: 0.3307
# Epoch 1: val_loss improved from inf to 1.46838, saving model to ../../models/FC211012_Azeem\emotion_detection_model.h5
# d:\New folder\Music_Recommendation_System\venv\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 770/770 [==============================] - 434s 555ms/step - loss: 1.5719 - accuracy: 0.3307 - val_loss: 1.4684 - val_accuracy: 0.3713
# Epoch 2/30
# 770/770 [==============================] - ETA: 0s - loss: 1.2134 - accuracy: 0.5061
# Epoch 2: val_loss improved from 1.46838 to 1.13821, saving model to ../../models/FC211012_Azeem\emotion_detection_model.h5
# 770/770 [==============================] - 426s 553ms/step - loss: 1.2134 - accuracy: 0.5061 - val_loss: 1.1382 - val_accuracy: 0.5419
# Epoch 3/30
# 770/770 [==============================] - ETA: 0s - loss: 1.0786 - accuracy: 0.5693
# Epoch 3: val_loss did not improve from 1.13821
# 770/770 [==============================] - 422s 548ms/step - loss: 1.0786 - accuracy: 0.5693 - val_loss: 1.7083 - val_accuracy: 0.4842
# Epoch 4/30
# 770/770 [==============================] - ETA: 0s - loss: 1.0055 - accuracy: 0.6026
# Epoch 4: val_loss improved from 1.13821 to 1.08337, saving model to ../../models/FC211012_Azeem\emotion_detection_model.h5
# 770/770 [==============================] - 445s 579ms/step - loss: 1.0055 - accuracy: 0.6026 - val_loss: 1.0834 - val_accuracy: 0.5691
# Epoch 5/30
# 770/770 [==============================] - ETA: 0s - loss: 0.9621 - accuracy: 0.6199
# Epoch 5: val_loss did not improve from 1.08337
# 770/770 [==============================] - 445s 578ms/step - loss: 0.9621 - accuracy: 0.6199 - val_loss: 1.0898 - val_accuracy: 0.5734
# Epoch 6/30
# 770/770 [==============================] - ETA: 0s - loss: 0.9309 - accuracy: 0.6351
# Epoch 6: val_loss improved from 1.08337 to 1.04816, saving model to ../../models/FC211012_Azeem\emotion_detection_model.h5
# 770/770 [==============================] - 448s 582ms/step - loss: 0.9309 - accuracy: 0.6351 - val_loss: 1.0482 - val_accuracy: 0.5951
# Epoch 7/30
# 770/770 [==============================] - ETA: 0s - loss: 0.9097 - accuracy: 0.6440
# Epoch 7: val_loss did not improve from 1.04816
# 770/770 [==============================] - 447s 580ms/step - loss: 0.9097 - accuracy: 0.6440 - val_loss: 1.0527 - val_accuracy: 0.5998
# Epoch 8/30
# 770/770 [==============================] - ETA: 0s - loss: 0.8900 - accuracy: 0.6511
# Epoch 8: val_loss improved from 1.04816 to 0.98402, saving model to ../../models/FC211012_Azeem\emotion_detection_model.h5
# 770/770 [==============================] - 496s 644ms/step - loss: 0.8900 - accuracy: 0.6511 - val_loss: 0.9840 - val_accuracy: 0.6154
# Epoch 9/30
# 770/770 [==============================] - ETA: 0s - loss: 0.8729 - accuracy: 0.6600
# Epoch 9: val_loss improved from 0.98402 to 0.93535, saving model to ../../models/FC211012_Azeem\emotion_detection_model.h5
# 770/770 [==============================] - 1151s 1s/step - loss: 0.8729 - accuracy: 0.6600 - val_loss: 0.9353 - val_accuracy: 0.6365
# Epoch 10/30
# 770/770 [==============================] - ETA: 0s - loss: 0.8533 - accuracy: 0.6704
# Epoch 10: val_loss did not improve from 0.93535
# 770/770 [==============================] - 381s 495ms/step - loss: 0.8533 - accuracy: 0.6704 - val_loss: 1.0591 - val_accuracy: 0.5931
# Epoch 11/30
# 770/770 [==============================] - ETA: 0s - loss: 0.8440 - accuracy: 0.6723
# Epoch 11: val_loss improved from 0.93535 to 0.90516, saving model to ../../models/FC211012_Azeem\emotion_detection_model.h5
# 770/770 [==============================] - 541s 703ms/step - loss: 0.8440 - accuracy: 0.6723 - val_loss: 0.9052 - val_accuracy: 0.6537
# Epoch 12/30
# 770/770 [==============================] - ETA: 0s - loss: 0.8271 - accuracy: 0.6805
# Epoch 12: val_loss did not improve from 0.90516
# 770/770 [==============================] - 407s 528ms/step - loss: 0.8271 - accuracy: 0.6805 - val_loss: 1.0242 - val_accuracy: 0.6186
# Epoch 13/30
# 770/770 [==============================] - ETA: 0s - loss: 0.8139 - accuracy: 0.6854
# Epoch 13: val_loss did not improve from 0.90516
# 770/770 [==============================] - 378s 491ms/step - loss: 0.8139 - accuracy: 0.6854 - val_loss: 1.4719 - val_accuracy: 0.4685
# Epoch 14/30
# 770/770 [==============================] - ETA: 0s - loss: 0.8021 - accuracy: 0.6916
# Epoch 14: val_loss improved from 0.90516 to 0.83903, saving model to ../../models/FC211012_Azeem\emotion_detection_model.h5
# 770/770 [==============================] - 379s 492ms/step - loss: 0.8021 - accuracy: 0.6916 - val_loss: 0.8390 - val_accuracy: 0.6765
# Epoch 15/30
# 770/770 [==============================] - ETA: 0s - loss: 0.7865 - accuracy: 0.6934
# Epoch 15: val_loss did not improve from 0.83903
# 770/770 [==============================] - 379s 492ms/step - loss: 0.7865 - accuracy: 0.6934 - val_loss: 1.0820 - val_accuracy: 0.6032
# Epoch 16/30
# 770/770 [==============================] - ETA: 0s - loss: 0.7830 - accuracy: 0.7002
# Epoch 16: val_loss did not improve from 0.83903
# 770/770 [==============================] - 378s 491ms/step - loss: 0.7830 - accuracy: 0.7002 - val_loss: 0.8872 - val_accuracy: 0.6462
# Epoch 17/30
# 754/770 [============================>.] - ETA: 1:26 - loss: 0.7791 - accuracy: 0.7043

# %% [markdown]
# ## Saving and evaluating the best model

# %%
# Plot accuracy and loss
plt.figure(figsize=(12, 5))

# 1.Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title("Model Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# 2.Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Get class indices to labels mapping
class_indices = val_generator.class_indices
idx_to_class = {v: k for k, v in class_indices.items()}

# Reset generator for fresh prediction
val_generator.reset()

# Predict class probabilities
y_probs = model.predict(val_generator, verbose=1)

# Get predicted and true labels
y_pred = np.argmax(y_probs, axis=1)
y_true = val_generator.classes
# Out:
# 193/193 [==============================] - 22s 112ms/step

# %% [markdown]
# ## Print classification metrics

# %%
report = classification_report(
    y_true, y_pred, target_names=idx_to_class.values())
print("Classification Report:\n")
print(report)
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#        happy       0.81      0.86      0.83      1774
#      neutral       0.54      0.70      0.61      1233
#          sad       0.51      0.65      0.57      1247
#     stressed       0.86      0.32      0.47      1069
#     surprise       0.89      0.70      0.78       831
#
#     accuracy                           0.67      6154
#    macro avg       0.72      0.65      0.65      6154
# weighted avg       0.71      0.67      0.66      6154

# %% [markdown]
# ## Compute and plot confusion matrix

# %%
cm = confusion_matrix(y_true, y_pred)

# Plot it
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=idx_to_class.values(),
            yticklabels=idx_to_class.values())
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Real-time inference using webcam + Haar Cascade + OpenCV

# %%
# Load model and face detector
model = load_model('../../models/FC211012_Azeem/emotion_detection_model.h5')
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
emotion_labels = ['happy', 'neutral', 'sad', 'surprise', 'stressed']

# Confidence threshold
CONFIDENCE_THRESHOLD = 0.7

# Start webcam
cap = cv2.VideoCapture(0)
print("[INFO] Starting webcam...")

ret, frame = cap.read()
if not ret:
    print("[ERROR] Unable to read from webcam.")
    cap.release()
else:
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(
        gray, scaleFactor=1.3, minNeighbors=5)

    for (x, y, w, h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi = cv2.resize(roi_gray, (48, 48)) / 255.0
        roi = np.expand_dims(roi, axis=(0, -1))

        preds = model.predict(roi, verbose=0)
        confidence = np.max(preds)
        label = emotion_labels[np.argmax(preds)]

        if confidence > CONFIDENCE_THRESHOLD:
            text = f"{label} ({confidence*100:.1f}%)"
            color = (0, 255, 0)
        else:
            text = "Uncertain"
            color = (0, 0, 255)

        # Draw rectangle and label
        cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
        cv2.putText(frame, text, (x, y - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)

    # Display using matplotlib
    plt.figure(figsize=(8, 6))
    plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.title("Detected Emotion")
    plt.show()

cap.release()
# Out:
# [INFO] Starting webcam...
